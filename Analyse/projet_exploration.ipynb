# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/andreaaraldo/machine-learning-for-networks/blob/master/01.introduction/a.exploration.ipynb)
#
#
# We use a the dataset of QoE prediction from [Requet dataset](https://github.com/Wimnet/RequetDataSet): Requet: Real-Time QoE Detection for Encrypted YouTube Traffic (preprocessed by me).
#
#
#
#
# Figures from [1]:
#
# ![alt text](https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/01.introduction/img/sys-diagram.png)
#
#
# ![alt text](https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/01.introduction/img/experimental.png)
#
#
# Load libraries

# %%
# %matplotlib inline
import pandas as pd # For dataframes (tables)
import numpy as np # For numerical operations
import math
import matplotlib.pyplot as plt # For plots
import os # To import external python files
import sys# To import external python files

from pandas.plotting import scatter_matrix

# This a comment...

# %% [markdown]
# Load the dataset previously preprocessed. ...

# %%
! ls
# Out:
# projet_exploration.ipynb

# %%
! pwd
# Out:
# /mnt/c/users/emili/Desktop/git world/NET4550/Analyse

# %%
df = pd.read_csv('../material/dataset.csv')

# %%
df.head(n=11)
# Out:
#         videoID          category  bitrates_144p  bitrates_240p  \
# 0   FWpRqKpV0rY         Education          76305         111936
# 1   n72yt5hc3-A   Travel & Events          91757         123729
# 2   v0_uAqzWlUM            Sports          91222         162811
# 3   aD3Ahnee0Ck  Film & Animation         104747         223032
# 4   x_5cNlOanxU            Sports          96304         221927
# 5   6PlXm459zcA            Sports          89165         198228
# 6   vZIbVJGrGGw     Entertainment          89618         174094
# 7   UsEiOB1cYC8  Film & Animation          93274         204879
# 8   vgHqqb2xO_w   Travel & Events          95300         218826
# 9   DAAKRAxLgbE            Sports          96755         223819
# 10  wD1puTtQWRo    People & Blogs          33628          76560
#
#     bitrates_360p  bitrates_480p  bitrates_720p  bitrates_1080p  join_time  \
# 0          204952         340239         744420         1683577       2883
# 1          195255         303189         682584         1385367       4803
# 2          305089         531184        1191866         2349128     310000
# 3          411669         682377        1345939         2442657     310000
# 4          410068         757581        1517988         2655758       7518
# 5          364203         668145        1331291         2404379     310000
# 6          325423         549375        1080947         2136578      12947
# 7          373458         661547        1281450         2235024       7501
# 8          396748         731752        1450308         2570114       6834
# 9          412695         757409        1509151         2648614     310000
# 10         139224         248352         488643          847700       3020
#
#     stallingNumber  ...  QoE_JT  QoE_noStall  QoE_noSwitches  QoE_Linear  \
# 0                0  ...       1            0               0     5.00000
# 1                0  ...       1            0               0     5.00000
# 2                0  ...       0            0               0     0.00000
# 3                0  ...       0            0               0     0.00000
# 4                0  ...       1            0               1     4.26099
# 5                0  ...       0            0               0     0.00000
# 6                2  ...       1            1               1     2.84523
# 7                0  ...       1            0               1     3.63736
# 8                0  ...       1            0               0     5.00000
# 9                0  ...       0            0               0     0.00000
# 10               0  ...       1            0               0     5.00000
#
#     QoE_Linear2  QoE_Linear3  QoE_LD_SD_HD  QoE_ITU_023  QoE_ITU_035  \
# 0       5.00000      5.00000             2       5.0000      4.61882
# 1       5.00000      5.00000             2       5.0000      4.58990
# 2       0.00000      0.00000             0       5.0000      4.68886
# 3       0.00000      0.00000             0      -1.0000     -1.00000
# 4       4.11676      3.87637             1       5.0000      4.03308
# 5       0.00000      0.00000             0      -1.0000     -1.00000
# 6       2.46930      1.94046             0       4.2142      2.22257
# 7       3.52198      3.32967             1       5.0000      3.39305
# 8       5.00000      5.00000             2       5.0000      4.79715
# 9       0.00000      0.00000             0       5.0000      4.72676
# 10      5.00000      5.00000             2       5.0000      4.41227
#
#     QoE_ITU_046
# 0       4.58419
# 1       4.55993
# 2       4.63004
# 3      -1.00000
# 4       4.01313
# 5      -1.00000
# 6       2.08231
# 7       3.30373
# 8       4.71794
# 9       4.65846
# 10      4.41186
#
# [11 rows x 270 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111918 entries, 0 to 111917
# Data columns (total 270 columns):
#  #    Column                         Dtype
# ---   ------                         -----
#  0    videoID                        object
#  1    category                       object
#  2    bitrates_144p                  int64
#  3    bitrates_240p                  int64
#  4    bitrates_360p                  int64
#  5    bitrates_480p                  int64
#  6    bitrates_720p                  int64
#  7    bitrates_1080p                 int64
#  8    join_time                      int64
#  9    stallingNumber                 int64
#  10   totalStallDuration             int64
#  11   outbandQoS_DL_TP               float64
#  12   outbandQoS_UL_TP               float64
#  13   outbandQoS_RTT                 float64
#  14   outbandQoS_RTT_STD             float64
#  15   outbandQoS_LOSS                float64
#  16   pcapStats_stats_avg_DL_TP      float64
#  17   pcapStats_stats_avg_UL_t       float64
#  18   pcapStats_stats_avg_DL_t       float64
#  19   pcapStats_stats_avg_DL_pkt     float64
#  20   pcapStats_stats_max_DL_TP      int64
#  21   pcapStats_stats_max_UL_t       float64
#  22   pcapStats_stats_max_DL_t       float64
#  23   pcapStats_stats_max_DL_pkt     int64
#  24   pcapStats_stats_std_DL_TP      float64
#  25   pcapStats_stats_std_UL_t       float64
#  26   pcapStats_stats_std_DL_t       float64
#  27   pcapStats_stats_std_DL_pkt     float64
#  28   pcapStats_stats_p10_DL_TP      float64
#  29   pcapStats_stats_p10_UL_t       float64
#  30   pcapStats_stats_p10_DL_t       float64
#  31   pcapStats_stats_p10_DL_pkt     float64
#  32   pcapStats_stats_p20_DL_TP      float64
#  33   pcapStats_stats_p20_UL_t       float64
#  34   pcapStats_stats_p20_DL_t       float64
#  35   pcapStats_stats_p20_DL_pkt     float64
#  36   pcapStats_stats_p30_DL_TP      float64
#  37   pcapStats_stats_p30_UL_t       float64
#  38   pcapStats_stats_p30_DL_t       float64
#  39   pcapStats_stats_p30_DL_pkt     float64
#  40   pcapStats_stats_p40_DL_TP      float64
#  41   pcapStats_stats_p40_UL_t       float64
#  42   pcapStats_stats_p40_DL_t       float64
#  43   pcapStats_stats_p40_DL_pkt     float64
#  44   pcapStats_stats_p50_DL_TP      int64
#  45   pcapStats_stats_p50_UL_t       float64
#  46   pcapStats_stats_p50_DL_t       float64
#  47   pcapStats_stats_p50_DL_pkt     float64
#  48   pcapStats_stats_p60_DL_TP      float64
#  49   pcapStats_stats_p60_UL_t       float64
#  50   pcapStats_stats_p60_DL_t       float64
#  51   pcapStats_stats_p60_DL_pkt     float64
#  52   pcapStats_stats_p70_DL_TP      float64
#  53   pcapStats_stats_p70_UL_t       float64
#  54   pcapStats_stats_p70_DL_t       float64
#  55   pcapStats_stats_p70_DL_pkt     float64
#  56   pcapStats_stats_p80_DL_TP      float64
#  57   pcapStats_stats_p80_UL_t       float64
#  58   pcapStats_stats_p80_DL_t       float64
#  59   pcapStats_stats_p80_DL_pkt     float64
#  60   pcapStats_stats_p90_DL_TP      float64
#  61   pcapStats_stats_p90_UL_t       float64
#  62   pcapStats_stats_p90_DL_t       float64
#  63   pcapStats_stats_p90_DL_pkt     float64
#  64   pcapStats_temporal_DLTP_t1     int64
#  65   pcapStats_temporal_DLTP_t2     int64
#  66   pcapStats_temporal_DLTP_t3     int64
#  67   pcapStats_temporal_DLTP_t4     int64
#  68   pcapStats_temporal_DLTP_t5     int64
#  69   pcapStats_temporal_DLTP_t6     int64
#  70   pcapStats_temporal_DLTP_t7     int64
#  71   pcapStats_temporal_DLTP_t8     int64
#  72   pcapStats_temporal_DLTP_t9     int64
#  73   pcapStats_temporal_DLTP_t10    int64
#  74   pcapStats_temporal_DLTP_t11    int64
#  75   pcapStats_temporal_DLTP_t12    int64
#  76   pcapStats_temporal_DLTP_t13    int64
#  77   pcapStats_temporal_DLTP_t14    int64
#  78   pcapStats_temporal_DLTP_t15    int64
#  79   pcapStats_temporal_DLTP_t16    int64
#  80   pcapStats_temporal_DLTP_t17    int64
#  81   pcapStats_temporal_DLTP_t18    int64
#  82   pcapStats_temporal_DLTP_t19    int64
#  83   pcapStats_temporal_DLTP_t20    int64
#  84   pcapStats_temporal_DLTP_t21    int64
#  85   pcapStats_temporal_DLTP_t22    int64
#  86   pcapStats_temporal_DLTP_t23    int64
#  87   pcapStats_temporal_DLTP_t24    int64
#  88   pcapStats_temporal_DLTP_t25    int64
#  89   pcapStats_temporal_DLTP_t26    int64
#  90   pcapStats_temporal_DLTP_t27    int64
#  91   pcapStats_temporal_DLTP_t28    int64
#  92   pcapStats_temporal_DLTP_t29    int64
#  93   pcapStats_temporal_DLTP_t30    int64
#  94   pcapStats_temporal_DLTP_t31    int64
#  95   pcapStats_temporal_DLTP_t32    int64
#  96   pcapStats_temporal_DLTP_t33    int64
#  97   pcapStats_temporal_DLTP_t34    int64
#  98   pcapStats_temporal_DLTP_t35    int64
#  99   pcapStats_temporal_DLTP_t36    int64
#  100  pcapStats_temporal_DLTP_t37    int64
#  101  pcapStats_temporal_DLTP_t38    int64
#  102  pcapStats_temporal_DLTP_t39    int64
#  103  pcapStats_temporal_DLTP_t40    int64
#  104  pcapStats_temporal_DLTP_t41    int64
#  105  pcapStats_temporal_DLTP_t42    int64
#  106  pcapStats_temporal_DLTP_t43    int64
#  107  pcapStats_temporal_DLTP_t44    int64
#  108  pcapStats_temporal_DLTP_t45    int64
#  109  pcapStats_temporal_DLTP_t46    int64
#  110  pcapStats_temporal_DLTP_t47    int64
#  111  pcapStats_temporal_DLTP_t48    int64
#  112  pcapStats_temporal_DLTP_t49    int64
#  113  pcapStats_temporal_DLTP_t50    int64
#  114  pcapStats_temporal_DLTP_t51    int64
#  115  pcapStats_temporal_DLTP_t52    int64
#  116  pcapStats_temporal_DLTP_t53    int64
#  117  pcapStats_temporal_DLTP_t54    int64
#  118  pcapStats_temporal_DLTP_t55    int64
#  119  pcapStats_temporal_DLTP_t56    int64
#  120  pcapStats_temporal_DLTP_t57    int64
#  121  pcapStats_temporal_DLTP_t58    int64
#  122  pcapStats_temporal_DLTP_t59    int64
#  123  pcapStats_temporal_DLTP_t60    int64
#  124  pcapStats_temporal_DLTP_t61    int64
#  125  pcapStats_temporal_DLTP_t62    int64
#  126  pcapStats_temporal_DLTP_t63    int64
#  127  pcapStats_temporal_DLTP_t64    int64
#  128  pcapStats_temporal_DLTP_t65    int64
#  129  pcapStats_temporal_DLTP_t66    int64
#  130  pcapStats_temporal_DLTP_t67    int64
#  131  pcapStats_temporal_DLTP_t68    int64
#  132  pcapStats_temporal_DLTP_t69    int64
#  133  pcapStats_temporal_DLTP_t70    int64
#  134  pcapStats_temporal_DLTP_t71    int64
#  135  pcapStats_temporal_DLTP_t72    int64
#  136  pcapStats_temporal_DLTP_t73    int64
#  137  pcapStats_temporal_DLTP_t74    int64
#  138  pcapStats_temporal_DLTP_t75    int64
#  139  pcapStats_temporal_DLTP_t76    int64
#  140  pcapStats_temporal_DLTP_t77    int64
#  141  pcapStats_temporal_DLTP_t78    int64
#  142  pcapStats_temporal_DLTP_t79    int64
#  143  pcapStats_temporal_DLTP_t80    int64
#  144  pcapStats_temporal_DLTP_t81    int64
#  145  pcapStats_temporal_DLTP_t82    int64
#  146  pcapStats_temporal_DLTP_t83    int64
#  147  pcapStats_temporal_DLTP_t84    int64
#  148  pcapStats_temporal_DLTP_t85    int64
#  149  pcapStats_temporal_DLTP_t86    int64
#  150  pcapStats_temporal_DLTP_t87    int64
#  151  pcapStats_temporal_DLTP_t88    int64
#  152  pcapStats_temporal_DLTP_t89    int64
#  153  pcapStats_temporal_DLTP_t90    int64
#  154  pcapStats_temporal_DLTP_t91    int64
#  155  pcapStats_temporal_DLTP_t92    int64
#  156  pcapStats_temporal_DLTP_t93    int64
#  157  pcapStats_temporal_DLTP_t94    int64
#  158  pcapStats_temporal_DLTP_t95    int64
#  159  pcapStats_temporal_DLTP_t96    int64
#  160  pcapStats_temporal_DLTP_t97    int64
#  161  pcapStats_temporal_DLTP_t98    int64
#  162  pcapStats_temporal_DLTP_t99    int64
#  163  pcapStats_temporal_DLTP_t100   int64
#  164  pcapStats_first30sec_DLTP_t1   int64
#  165  pcapStats_first30sec_DLTP_t2   int64
#  166  pcapStats_first30sec_DLTP_t3   int64
#  167  pcapStats_first30sec_DLTP_t4   int64
#  168  pcapStats_first30sec_DLTP_t5   int64
#  169  pcapStats_first30sec_DLTP_t6   int64
#  170  pcapStats_first30sec_DLTP_t7   int64
#  171  pcapStats_first30sec_DLTP_t8   int64
#  172  pcapStats_first30sec_DLTP_t9   int64
#  173  pcapStats_first30sec_DLTP_t10  int64
#  174  pcapStats_first30sec_DLTP_t11  int64
#  175  pcapStats_first30sec_DLTP_t12  int64
#  176  pcapStats_first30sec_DLTP_t13  int64
#  177  pcapStats_first30sec_DLTP_t14  int64
#  178  pcapStats_first30sec_DLTP_t15  int64
#  179  pcapStats_first30sec_DLTP_t16  int64
#  180  pcapStats_first30sec_DLTP_t17  int64
#  181  pcapStats_first30sec_DLTP_t18  int64
#  182  pcapStats_first30sec_DLTP_t19  int64
#  183  pcapStats_first30sec_DLTP_t20  int64
#  184  pcapStats_first30sec_DLTP_t21  int64
#  185  pcapStats_first30sec_DLTP_t22  int64
#  186  pcapStats_first30sec_DLTP_t23  int64
#  187  pcapStats_first30sec_DLTP_t24  int64
#  188  pcapStats_first30sec_DLTP_t25  int64
#  189  pcapStats_first30sec_DLTP_t26  int64
#  190  pcapStats_first30sec_DLTP_t27  int64
#  191  pcapStats_first30sec_DLTP_t28  int64
#  192  pcapStats_first30sec_DLTP_t29  int64
#  193  pcapStats_first30sec_DLTP_t30  int64
#  194  totalDuration                  float64
#  195  totalPacketCount               int64
#  196  numberOfVideoChunks            int64
#  197  numberOfAudioChunks            int64
#  198  ratioOfChunksHTTP              float64
#  199  videoChunkSizesHTTP_avg        float64
#  200  videoChunkSizesHTTP_std        float64
#  201  videoChunkSizesHTTP_min        int64
#  202  videoChunkSizesHTTP_max        int64
#  203  videoChunkSizesHTTP_p25        float64
#  204  videoChunkSizesHTTP_p50        float64
#  205  videoChunkSizesHTTP_p75        float64
#  206  audioChunkSizesHTTP_avg        float64
#  207  audioChunkSizesHTTP_std        float64
#  208  audioChunkSizesHTTP_min        int64
#  209  audioChunkSizesHTTP_max        int64
#  210  audioChunkSizesHTTP_p25        float64
#  211  audioChunkSizesHTTP_p50        float64
#  212  audioChunkSizesHTTP_p75        float64
#  213  videoChunkDursHTTP_avg         float64
#  214  videoChunkDursHTTP_std         float64
#  215  videoChunkDursHTTP_min         int64
#  216  videoChunkDursHTTP_max         int64
#  217  videoChunkDursHTTP_p25         float64
#  218  videoChunkDursHTTP_p50         float64
#  219  videoChunkDursHTTP_p75         float64
#  220  audioChunkDursHTTP_avg         float64
#  221  audioChunkDursHTTP_std         float64
#  222  audioChunkDursHTTP_min         int64
#  223  audioChunkDursHTTP_max         int64
#  224  audioChunkDursHTTP_p25         float64
#  225  audioChunkDursHTTP_p50         float64
#  226  audioChunkDursHTTP_p75         float64
#  227  chunkSizesPcap_avg             float64
#  228  chunkSizesPcap_std             float64
#  229  chunkSizesPcap_min             int64
#  230  chunkSizesPcap_max             int64
#  231  chunkSizesPcap_p25             float64
#  232  chunkSizesPcap_p50             float64
#  233  chunkSizesPcap_p75             float64
#  234  chunkSizesPcapVideo_avg        float64
#  235  chunkSizesPcapVideo_std        float64
#  236  chunkSizesPcapVideo_min        int64
#  237  chunkSizesPcapVideo_max        int64
#  238  chunkSizesPcapVideo_p25        float64
#  239  chunkSizesPcapVideo_p50        float64
#  240  chunkSizesPcapVideo_p75        float64
#  241  chunkSizesPcapAudio_avg        float64
#  242  chunkSizesPcapAudio_std        float64
#  243  chunkSizesPcapAudio_min        int64
#  244  chunkSizesPcapAudio_max        int64
#  245  chunkSizesPcapAudio_p25        float64
#  246  chunkSizesPcapAudio_p50        float64
#  247  chunkSizesPcapAudio_p75        float64
#  248  kmeansCenterVideo              float64
#  249  kmeansCenterAudio              float64
#  250  avgResQual                     float64
#  251  stdResQual                     float64
#  252  maxResQual                     int64
#  253  numberOfPosSwitches            int64
#  254  numberOfNegSwitches            int64
#  255  totalSwitches                  int64
#  256  totalSwitchesAccumalate        int64
#  257  numberOfPosSwitchesAcc         int64
#  258  numberOfNegSwitchesAcc         int64
#  259  dur                            float64
#  260  QoE_JT                         int64
#  261  QoE_noStall                    int64
#  262  QoE_noSwitches                 int64
#  263  QoE_Linear                     float64
#  264  QoE_Linear2                    float64
#  265  QoE_Linear3                    float64
#  266  QoE_LD_SD_HD                   int64
#  267  QoE_ITU_023                    float64
#  268  QoE_ITU_035                    float64
#  269  QoE_ITU_046                    float64
# dtypes: float64(98), int64(170), object(2)
# memory usage: 230.5+ MB

# %% [markdown]
# We first check the meaning from the repository [Requet dataset](https://github.com/Wimnet/RequetDataSet).

# %% [markdown]
# Check the possbile values that a certain feature can take

# %%
print ("Values of label: ",  df['category'].unique() )
print ("Values of bitrates_144p: ",  df['bitrates_144p'].unique() )
# Out:
# Values of label:  ['Education' 'Travel & Events' 'Sports' 'Film & Animation' 'Entertainment'
#  'People & Blogs' 'Music' 'Howto & Style' 'News & Politics'
#  'Science & Technology' 'Autos & Vehicles' 'Gaming' 'Pets & Animals'
#  'Comedy' 'Nonprofits & Activism' 'Shows' 'Trailers' 'Movies' nan]
# Values of bitrates_144p:  [76305 91757 91222 ... 37673 56312 82387]

# %% [markdown]
# # Basic statistics
#
# How many samples and columns are present in our dataset?

# %%
df.shape
# Out:
# (111918, 270)

# %%
df.describe()
# Out:
#        bitrates_144p  bitrates_240p  bitrates_360p  bitrates_480p  \
# count  111918.000000  111918.000000   1.119180e+05   1.119180e+05
# mean    84332.731947  161489.302391   2.969431e+05   5.182033e+05
# std     20668.887859   56534.360684   1.052568e+05   1.989775e+05
# min         0.000000       0.000000   0.000000e+00   0.000000e+00
# 25%     80331.000000  123169.250000   2.260465e+05   3.745588e+05
# 50%     91811.000000  173440.000000   3.190810e+05   5.480490e+05
# 75%     96949.000000  208920.750000   3.848445e+05   6.891848e+05
# max    224840.000000  912737.000000   1.737032e+06   2.469066e+06
#
#        bitrates_720p  bitrates_1080p      join_time  stallingNumber  \
# count   1.119180e+05    1.119180e+05  111918.000000   111918.000000
# mean    1.042122e+06    1.942912e+06   25931.308011        0.261647
# std     4.036120e+05    7.196381e+05   75781.567901        1.021500
# min     0.000000e+00    6.503000e+03     424.000000        0.000000
# 25%     7.559112e+05    1.466818e+06    2150.000000        0.000000
# 50%     1.104771e+06    2.096554e+06    3627.000000        0.000000
# 75%     1.388101e+06    2.536444e+06    9592.000000        0.000000
# max     6.597562e+06    1.617896e+07  310000.000000       55.000000
#
#        totalStallDuration  outbandQoS_DL_TP  ...         QoE_JT  \
# count        1.119180e+05     111918.000000  ...  111918.000000
# mean         8.439044e+02       2718.630525  ...       0.933871
# std          8.400947e+03       2214.812704  ...       0.248508
# min          0.000000e+00         14.413600  ...       0.000000
# 25%          0.000000e+00        959.405750  ...       1.000000
# 50%          0.000000e+00       2160.460000  ...       1.000000
# 75%          0.000000e+00       3958.375000  ...       1.000000
# max          1.149329e+06      10000.900000  ...       1.000000
#
#          QoE_noStall  QoE_noSwitches     QoE_Linear    QoE_Linear2  \
# count  111918.000000   111918.000000  111918.000000  111918.000000
# mean        0.113601        0.678541       3.701094       3.580076
# std         0.317327        0.467038       1.442906       1.488463
# min         0.000000        0.000000       0.000000       0.000000
# 25%         0.000000        0.000000       2.977380       2.711540
# 50%         0.000000        1.000000       4.221490       4.086810
# 75%         0.000000        1.000000       4.897620       4.854170
# max         1.000000        1.000000       5.000000       5.000000
#
#          QoE_Linear3   QoE_LD_SD_HD    QoE_ITU_023    QoE_ITU_035  \
# count  111918.000000  111918.000000  111918.000000  111918.000000
# mean        3.421931       1.118346       4.701970       3.508716
# std         1.536845       0.848809       1.103952       1.218094
# min         0.000000       0.000000      -1.000000      -1.000000
# 25%         2.354348       0.000000       5.000000       2.888690
# 50%         3.929890       1.000000       5.000000       3.816150
# 75%         4.784930       2.000000       5.000000       4.440977
# max         5.000000       2.000000       5.000000       5.000000
#
#          QoE_ITU_046
# count  111918.000000
# mean        3.477911
# std         1.224799
# min        -1.000000
# 25%         2.812635
# 50%         3.833190
# 75%         4.423617
# max         4.922150
#
# [8 rows x 268 columns]

# %% [markdown]
# If we want to see all columns:

# %%
# Trick from https://stackoverflow.com/q/24524104/2110769
with pd.option_context('display.max_columns', df.shape[1]):
    print(df.describe(include='all'))
# Out:
#             videoID       category  bitrates_144p  bitrates_240p  \
# count        111918         111915  111918.000000  111918.000000
# unique        99963             18            NaN            NaN
# top     rT0_PATyTJ4  Entertainment            NaN            NaN
# freq              5          21442            NaN            NaN
# mean            NaN            NaN   84332.731947  161489.302391
# std             NaN            NaN   20668.887859   56534.360684
# min             NaN            NaN       0.000000       0.000000
# 25%             NaN            NaN   80331.000000  123169.250000
# 50%             NaN            NaN   91811.000000  173440.000000
# 75%             NaN            NaN   96949.000000  208920.750000
# max             NaN            NaN  224840.000000  912737.000000
#
#         bitrates_360p  bitrates_480p  bitrates_720p  bitrates_1080p  \
# count    1.119180e+05   1.119180e+05   1.119180e+05    1.119180e+05
# unique            NaN            NaN            NaN             NaN
# top               NaN            NaN            NaN             NaN
# freq              NaN            NaN            NaN             NaN
# mean     2.969431e+05   5.182033e+05   1.042122e+06    1.942912e+06
# std      1.052568e+05   1.989775e+05   4.036120e+05    7.196381e+05
# min      0.000000e+00   0.000000e+00   0.000000e+00    6.503000e+03
# 25%      2.260465e+05   3.745588e+05   7.559112e+05    1.466818e+06
# 50%      3.190810e+05   5.480490e+05   1.104771e+06    2.096554e+06
# unique                         NaN                         NaN
# top                            NaN                         NaN
# freq                           NaN                         NaN
# mean                  5.581902e+05                9.756980e+05
# std                   4.759792e+05                1.079608e+06
# min                   3.410000e+02                0.000000e+00
# 25%                   2.477112e+05                2.247398e+05
# 50%                   4.509305e+05                6.337655e+05
# 75%                   7.201570e+05                1.323014e+06
# max                   7.941297e+06                1.163616e+07
#
#         pcapStats_temporal_DLTP_t3  pcapStats_temporal_DLTP_t4  \
# count                 1.119180e+05                1.119180e+05
# unique                         NaN                         NaN
# top                            NaN                         NaN
# freq                           NaN                         NaN
# mean                  1.246803e+06                1.433531e+06
# std                   1.491250e+06                1.688715e+06
# min                   0.000000e+00                0.000000e+00
# 25%                   1.919228e+05                1.954672e+05
# 50%                   6.957540e+05                8.096425e+05
# 75%                   1.765329e+06                2.107141e+06
# max                   1.446351e+07                2.504715e+07
#
#         pcapStats_temporal_DLTP_t5  pcapStats_temporal_DLTP_t6  \
# count                 1.119180e+05                1.119180e+05
# unique                         NaN                         NaN
# top                            NaN                         NaN
# freq                           NaN                         NaN
# mean                  1.552917e+06                1.613286e+06
# std                   1.788393e+06                1.824058e+06
# min                   0.000000e+00                0.000000e+00
# 25%                   2.166305e+05                2.359722e+05
# 50%                   9.213985e+05                1.000100e+06
# 75%                   2.290921e+06                2.374116e+06
# max                   1.714574e+07                1.920541e+07
#
#         pcapStats_temporal_DLTP_t7  pcapStats_temporal_DLTP_t8  \
# count                 1.119180e+05                1.119180e+05
# unique                         NaN                         NaN
# top                            NaN                         NaN
# freq                           NaN                         NaN
# mean                  1.665090e+06                1.700226e+06
# std                   1.854704e+06                1.875705e+06
# min                   0.000000e+00                0.000000e+00
# 25%                   2.578165e+05                2.775732e+05
# 50%                   1.059484e+06                1.113929e+06
# 75%                   2.445548e+06                2.477672e+06
# max                   1.825069e+07                1.918151e+07
#
#         pcapStats_temporal_DLTP_t9  pcapStats_temporal_DLTP_t10  \
# count                 1.119180e+05                 1.119180e+05
# unique                         NaN                          NaN
# top                            NaN                          NaN
# freq                           NaN                          NaN
# mean                  1.714209e+06                 1.724547e+06
# std                   1.882718e+06                 1.884305e+06
# min                   0.000000e+00                 0.000000e+00
# 25%                   2.895555e+05                 3.006218e+05
# 50%                   1.138784e+06                 1.154776e+06
# 75%                   2.499261e+06                 2.500262e+06
# max                   2.393822e+07                 2.047446e+07
#
#         pcapStats_temporal_DLTP_t11  pcapStats_temporal_DLTP_t12  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.736599e+06                 1.743080e+06
# std                    1.887965e+06                 1.890959e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.110760e+05                 3.181315e+05
# 50%                    1.183092e+06                 1.195820e+06
# 75%                    2.519784e+06                 2.521939e+06
# max                    2.045331e+07                 2.276927e+07
#
#         pcapStats_temporal_DLTP_t13  pcapStats_temporal_DLTP_t14  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.730933e+06                 1.718412e+06
# std                    1.868183e+06                 1.870332e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.182025e+05                 3.132665e+05
# 50%                    1.194956e+06                 1.186886e+06
# 75%                    2.505427e+06                 2.487890e+06
# max                    2.764975e+07                 2.866515e+07
#
#         pcapStats_temporal_DLTP_t15  pcapStats_temporal_DLTP_t16  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.721344e+06                 1.722263e+06
# std                    1.874967e+06                 1.871801e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.085518e+05                 3.144320e+05
# 50%                    1.191016e+06                 1.196567e+06
# 75%                    2.488318e+06                 2.491754e+06
# max                    2.465034e+07                 3.341603e+07
#
#         pcapStats_temporal_DLTP_t17  pcapStats_temporal_DLTP_t18  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1
+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.022578e+05                 3.077852e+05
# 50%                    1.192024e+06                 1.194359e+06
# 75%                    2.425182e+06                 2.425650e+06
# max                    3.594050e+07                 4.619428e+07
#
#         pcapStats_temporal_DLTP_t37  pcapStats_temporal_DLTP_t38  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.672401e+06                 1.678353e+06
# std                    1.808545e+06                 1.842084e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.068045e+05                 3.141028e+05
# 50%                    1.198396e+06                 1.196574e+06
# 75%                    2.427678e+06                 2.421477e+06
# max                    2.953849e+07                 3.236013e+07
#
#         pcapStats_temporal_DLTP_t39  pcapStats_temporal_DLTP_t40  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.678769e+06                 1.671938e+06
# std                    1.843824e+06                 1.824199e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.085832e+05                 3.089980e+05
# 50%                    1.194706e+06                 1.188806e+06
# 75%                    2.425820e+06                 2.415948e+06
# max                    3.772962e+07                 3.317753e+07
#
#         pcapStats_temporal_DLTP_t41  pcapStats_temporal_DLTP_t42  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.678418e+06                 1.672317e+06
# std                    1.840806e+06                 1.844910e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.080468e+05                 3.020758e+05
# 50%                    1.201879e+06                 1.193648e+06
# 75%                    2.419003e+06                 2.411049e+06
# max                    4.390583e+07                 4.398552e+07
#
#         pcapStats_temporal_DLTP_t43  pcapStats_temporal_DLTP_t44  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.671482e+06                 1.681101e+06
# std                    1.830223e+06                 1.836469e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.060888e+05                 3.189495e+05
# 50%                    1.193938e+06                 1.201973e+06
# 75%                    2.418071e+06                 2.423659e+06
# max                    4.421272e+07                 3.371536e+07
#
#         pcapStats_temporal_DLTP_t45  pcapStats_temporal_DLTP_t46  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.685251e+06                 1.674647e+06
# std                    1.848690e+06                 1.825497e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.171515e+05                 3.191098e+05
# 50%                    1.203592e+06                 1.203721e+06
# 75%                    2.434131e+06                 2.419022e+06
# max                    3.962694e+07                 3.117752e+07
#
#         pcapStats_temporal_DLTP_t47  pcapStats_temporal_DLTP_t48  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.661593e+06                 1.667580e+06
# std                    1.804869e+06                 1.827744e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.116448e+05                 3.080460e+05
# 50%                    1.197128e+06                 1.200170e+06
# 75%                    2.407827e+06                 2.410167e+06
# max                    3.478380e+07                 4.269635e+07
#
#         pcapStats_temporal_DLTP_t49  pcapStats_temporal_DLTP_t50  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.662347e+06                 1.656200e+06
# std                    1.819068e+06                 1.809438e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.076712e+05                 3.087315e+05
# 50%                    1.194662e+06                 1.185454e+06
# 75%                    2.414457e+06                 2.398203e+06
# max                    4.454887e+07                 3.881714e+07
#
#         pcapStats_temporal_DLTP_t51  pcapStats_temporal_DLTP_t52  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.675888e+06                 1.669558e+06
# std                    1.842737e+06                 1.828593e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.109680e+05                 3.149158e+05
# 50%                    1.200506e+06                 1.201825e+06
# 75%                    2.423399e+06                 2.413642e+06
# max                    3.550459e+07                 3.965481e+07
#
#         pcapStats_temporal_DLTP_t53  pcapStats_temporal_DLTP_t54  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.670696e+06                 1.669598e+06
# std                    1.832071e+06                 1.833124e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.132202e+05                 3.198428e+05
# 50%                    1.202079e+06                 1.203036e+06
# 75%                    2.413115e+06                 2.411936e+06
# max                    3.901471e+07                 5.473280e+07
#
#         pcapStats_temporal_DLTP_t55  pcapStats_temporal_DLTP_t56  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.666430e+06                 1.656639e+06
# std                    1.834354e+06                 1.810783e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.134232e+05                 3.057915e+05
# 50%                    1.198656e+06                 1.192572e+06
# 75%                    2.404698e+06                 2.389680e+06
# max                    4.310363e+07                 3.783240e+07
#
#         pcapStats_temporal_DLTP_t57  pcapStats_temporal_DLTP_t58  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.658779e+06                 1.662572e+06
# std                    1.818033e+06                 1.823112e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.048180e+05                 3.124848e+05
# 50%                    1.191310e+06                 1.197256e+06
# 75%                    2.400050e+06                 2.405706e+06
# max                    4.263883e+07                 5.148325e+07
#
#         pcapStats_temporal_DLTP_t59  pcapStats_temporal_DLTP_t60  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.661126e+06                 1.651617e+06
# std                    1.824157e+06                 1.819823e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.124648e+05                 3.075898e+05
# 50%                    1.191948e+06                 1.185017e+06
# 75%                    2.395682e+06                 2.385838e+06
# max                    5.444817e+07                 3.802510e+07
#
#         pcapStats_temporal_DLTP_t61  pcapStats_temporal_DLTP_t62  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.649125e+06                 1.651975e+06
# std                    1.816387e+06                 1.818013e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.024882e+05                 3.054262e+05
# 50%                    1.184402e+06                 1.185524e+06
# 75%                    2.387154e+06                 2.398497e+06
# max                    3.794339e+07                 4.373003e+07
#
#         pcapStats_temporal_DLTP_t63  pcapStats_temporal_DLTP_t64  \
# count                  1.119180e+05                 1.119180e+05
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   1.651169e+06                 1.643201e+06
# std                    1.805293e+06                 1.797782e+06
# min                    0.000000e+00                 0.000000e+00
# 25%                    3.067940e+05                 3.047312e+05
# 50%                    1.186070e+06                 1.181846e+06
# 75%                    2.394600e+06                 2.380894e+06
# max                    4.043070e+07                 3.547338e+07
#
# ...
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean               7795.014109             1653.275602
# std                5230.651079             1035.715012
# min                   0.000000                0.000000
# 25%                4037.000000              896.000000
# 50%                7004.000000             1551.375000
# 75%               10777.000000             2253.000000
# max               94411.000000            12247.000000
#
#         videoChunkDursHTTP_p50  videoChunkDursHTTP_p75  \
# count            111918.000000           111918.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean               2926.763590             4614.410901
# std                1684.295385             2710.218527
# min                   0.000000                0.000000
# 25%                1791.000000             2851.562500
# 50%                2840.000000             4405.000000
# 75%                3963.000000             6117.750000
# max               21052.000000            69067.000000
#
#         audioChunkDursHTTP_avg  audioChunkDursHTTP_std  \
# count            111918.000000           111918.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean               1373.407641              695.803402
# std                1144.435734              645.351531
# min                   0.000000                0.000000
# 25%                 658.400000              262.655750
# 50%                1028.630000              489.771500
# 75%                1732.390000              928.509750
# max               13302.500000             9085.920000
#
#         audioChunkDursHTTP_min  audioChunkDursHTTP_max  \
# count            111918.000000           111918.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                499.235413             2738.622563
# std                 454.047831             2500.306744
# min                   0.000000                0.000000
# 25%                 220.000000             1115.000000
# 50%                 406.000000             1918.000000
# 75%                 639.000000             3551.000000
# max               10546.000000            35205.000000
#
#         audioChunkDursHTTP_p25  audioChunkDursHTTP_p50  \
# count            111918.000000           111918.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                858.530402             1226.189273
# std                 771.912886             1051.761154
# unique                     NaN                     NaN            NaN
# top                        NaN                     NaN            NaN
# freq                       NaN                     NaN            NaN
# mean                  1.832753                1.592773     116.735919
# std                   1.899664                2.023041      68.714127
# min                   0.000000                0.000000       0.000000
# 25%                   0.000000                0.000000      60.366000
# 50%                   2.000000                1.000000     116.950000
# 75%                   3.000000                2.000000     175.141000
# max                  14.000000               14.000000     240.000000
#
#                QoE_JT    QoE_noStall  QoE_noSwitches     QoE_Linear  \
# count   111918.000000  111918.000000   111918.000000  111918.000000
# unique            NaN            NaN             NaN            NaN
# top               NaN            NaN             NaN            NaN
# freq              NaN            NaN             NaN            NaN
# mean         0.933871       0.113601        0.678541       3.701094
# std          0.248508       0.317327        0.467038       1.442906
# min          0.000000       0.000000        0.000000       0.000000
# 25%          1.000000       0.000000        0.000000       2.977380
# 50%          1.000000       0.000000        1.000000       4.221490
# 75%          1.000000       0.000000        1.000000       4.897620
# max          1.000000       1.000000        1.000000       5.000000
#
#           QoE_Linear2    QoE_Linear3   QoE_LD_SD_HD    QoE_ITU_023  \
# count   111918.000000  111918.000000  111918.000000  111918.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         3.580076       3.421931       1.118346       4.701970
# std          1.488463       1.536845       0.848809       1.103952
# min          0.000000       0.000000       0.000000      -1.000000
# 25%          2.711540       2.354348       0.000000       5.000000
# 50%          4.086810       3.929890       1.000000       5.000000
# 75%          4.854170       4.784930       2.000000       5.000000
# max          5.000000       5.000000       2.000000       5.000000
#
#           QoE_ITU_035    QoE_ITU_046
# count   111918.000000  111918.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean         3.508716       3.477911
# std          1.218094       1.224799
# min         -1.000000      -1.000000
# 25%          2.888690       2.812635
# 50%          3.816150       3.833190
# 75%          4.440977       4.423617
# max          5.000000       4.922150

# %% [markdown]
# ## 1st and 2nd order statistics

# %% [markdown]
# If we have $m$ samples
# Statistics of the $j$-th feature:
#
# |<span> | | |
# |---------------|-------|:--|
# | Mean| $
#     \mu_j \triangleq $  $    \frac{1}{m} \sum_{i=1}^m
#         x_j^{(i)}
# $ |
# |Variance| $
#     \text{Var}_j \triangleq$      $\frac{1}{m-1} \sum_{i=1}^m
#         \left( x_j^{(i)} - \mu_j \right)^2
# $|
# |Standard deviation|$
# \sigma_j \triangleq $ | $ \sqrt{\text{Var}_j}
# $|
#
#
# Note: Why $m-1$? See [Wikipedia](https://en.wikipedia.org/wiki/Variance#Sample_variance) (Not important to retain).

# %% [markdown]
# ## Boxplot

# %% [markdown]
# It represents minimum, percentiles (25%,50%,75%) and maximum.

# %%
df.boxplot(column=['bitrates_144p'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Percentiles

# %% [markdown]
# How are 25%, 50% (median) and 75% percentiles computed?

# %%
X = df['bitrates_144p'].values
X
# Out:
# array([ 76305,  91757,  91222, ...,  82793,  82387, 100974])

# %% [markdown]
# Order the values

# %%
X_sorted = np.sort(X)
X_sorted
# Out:
# array([     0,      0,      0, ..., 202940, 202940, 224840])

# %% [markdown]
# Visit the elements and stop when you visited 25%

# %%
K = X_sorted.size
stop = K/100 * 25
print ('stop=',stop)
stop = math.ceil(stop)
print ('stop=',stop)
print('The 25% percentile is ', X_sorted[stop])
# Out:
# stop= 27979.5
# stop= 27980
# The 25% percentile is  80331

# %% [markdown]
# **Meaning**: 25% of the values are $\le$ 7.

# %% [markdown]
# #### Outliers

# %% [markdown]
# First compute the Inter-Quartile range (range of the box):
#     \begin{align}
#     \text{IQR} \triangleq p_{75\%} - p_{25\%}
#     \end{align}
#
#
# Upper __whisker__ : $\min(p_{75\%} + 1.5 \cdot \text{IQR}, \text{max_value} )$
#
# Lower __whisker__ : $\max(p_{25\%} - 1.5 \cdot \text{IQR}, \text{min_value} )$
#
# All points outside are considered **outliers**

# %% [markdown]
# We can print the box plots of many columns

# %%
df.boxplot(column=['bitrates_144p', 'bitrates_240p'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can print boxplots for different values of a column

# %%
df.boxplot(column=['bitrates_144p', 'bitrates_240p'], by="category", figsize=(10,5))
# Out:
# array([<AxesSubplot:title={'center':'bitrates_144p'}, xlabel='category'>,
#        <AxesSubplot:title={'center':'bitrates_240p'}, xlabel='category'>],
#       dtype=object)

# %% [markdown]
# ## Histogram

# %% [markdown]
# We can plot the histogram of all the features

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'bitrates_144p'}>,
#         <AxesSubplot:title={'center':'bitrates_240p'}>,
#         <AxesSubplot:title={'center':'bitrates_360p'}>,
#         <AxesSubplot:title={'center':'bitrates_480p'}>,
#         <AxesSubplot:title={'center':'bitrates_720p'}>,
#         <AxesSubplot:title={'center':'bitrates_1080p'}>,
#         <AxesSubplot:title={'center':'join_time'}>,
#         <AxesSubplot:title={'center':'stallingNumber'}>,
#         <AxesSubplot:title={'center':'totalStallDuration'}>,
#         <AxesSubplot:title={'center':'outbandQoS_DL_TP'}>,
#         <AxesSubplot:title={'center':'outbandQoS_UL_TP'}>,
#         <AxesSubplot:title={'center':'outbandQoS_RTT'}>,
#         <AxesSubplot:title={'center':'outbandQoS_RTT_STD'}>,
#         <AxesSubplot:title={'center':'outbandQoS_LOSS'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_avg_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_avg_UL_t'}>],
#        [<AxesSubplot:title={'center':'pcapStats_stats_avg_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_avg_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_max_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_max_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_max_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_max_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_std_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_std_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_std_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_std_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p10_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p10_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p10_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p10_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p20_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p20_UL_t'}>],
#        [<AxesSubplot:title={'center':'pcapStats_stats_p20_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p20_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p30_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p30_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p30_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p30_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p40_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p40_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p40_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p40_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p50_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p50_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p50_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p50_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p60_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p60_UL_t'}>],
#        [<AxesSubplot:title={'center':'pcapStats_stats_p60_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p60_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p70_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p70_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p70_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p70_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p80_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p80_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p80_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p80_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p90_DL_TP'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p90_UL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p90_DL_t'}>,
#         <AxesSubplot:title={'center':'pcapStats_stats_p90_DL_pkt'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t1'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t2'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t3'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t4'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t5'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t6'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t7'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t8'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t9'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t10'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t11'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t12'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t13'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t14'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t15'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t16'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t17'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t18'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t19'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t20'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t21'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t22'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t23'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t24'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t25'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t26'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t27'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t28'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t29'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t30'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t31'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t32'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t33'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t34'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t35'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t36'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t37'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t38'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t39'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t40'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t41'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t42'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t43'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t44'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t45'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t46'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t47'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t48'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t49'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t50'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t51'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t52'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t53'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t54'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t55'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t56'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t57'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t58'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t59'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t60'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t61'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t62'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t63'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t64'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t65'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t66'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t67'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t68'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t69'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t70'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t71'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t72'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t73'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t74'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t75'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t76'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t77'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t78'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t79'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t80'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t81'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t82'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t83'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t84'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t85'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t86'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t87'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t88'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t89'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t90'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t91'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t92'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t93'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t94'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t95'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t96'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t97'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t98'}>],
#        [<AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t99'}>,
#         <AxesSubplot:title={'center':'pcapStats_temporal_DLTP_t100'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t1'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t2'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t3'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t4'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t5'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t6'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t7'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t8'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t9'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t10'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t11'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t12'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t13'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t14'}>],
#        [<AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t15'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t16'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t17'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t18'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t19'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t20'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t21'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t22'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t23'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t24'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t25'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t26'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t27'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t28'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t29'}>,
#         <AxesSubplot:title={'center':'pcapStats_first30sec_DLTP_t30'}>],
#        [<AxesSubplot:title={'center':'totalDuration'}>,
#         <AxesSubplot:title={'center':'totalPacketCount'}>,
#         <AxesSubplot:title={'center':'numberOfVideoChunks'}>,
#         <AxesSubplot:title={'center':'numberOfAudioChunks'}>,
#         <AxesSubplot:title={'center':'ratioOfChunksHTTP'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_avg'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_std'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_min'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_max'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_p25'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_p50'}>,
#         <AxesSubplot:title={'center':'videoChunkSizesHTTP_p75'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_avg'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_std'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_min'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_max'}>],
#        [<AxesSubplot:title={'center':'audioChunkSizesHTTP_p25'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_p50'}>,
#         <AxesSubplot:title={'center':'audioChunkSizesHTTP_p75'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_avg'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_std'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_min'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_max'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_p25'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_p50'}>,
#         <AxesSubplot:title={'center':'videoChunkDursHTTP_p75'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_avg'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_std'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_min'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_max'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_p25'}>,
#         <AxesSubplot:title={'center':'audioChunkDursHTTP_p50'}>],
#        [<AxesSubplot:title={'center':'audioChunkDursHTTP_p75'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_avg'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_std'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_min'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_max'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_p25'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_p50'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcap_p75'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_avg'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_std'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_min'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_max'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_p25'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_p50'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapVideo_p75'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_avg'}>],
#        [<AxesSubplot:title={'center':'chunkSizesPcapAudio_std'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_min'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_max'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_p25'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_p50'}>,
#         <AxesSubplot:title={'center':'chunkSizesPcapAudio_p75'}>,
#         <AxesSubplot:title={'center':'kmeansCenterVideo'}>,
#         <AxesSubplot:title={'center':'kmeansCenterAudio'}>,
#         <AxesSubplot:title={'center':'avgResQual'}>,
#         <AxesSubplot:title={'center':'stdResQual'}>,
#         <AxesSubplot:title={'center':'maxResQual'}>,
#         <AxesSubplot:title={'center':'numberOfPosSwitches'}>,
#         <AxesSubplot:title={'center':'numberOfNegSwitches'}>,
#         <AxesSubplot:title={'center':'totalSwitches'}>,
#         <AxesSubplot:title={'center':'totalSwitchesAccumalate'}>,
#         <AxesSubplot:title={'center':'numberOfPosSwitchesAcc'}>],
#        [<AxesSubplot:title={'center':'numberOfNegSwitchesAcc'}>,
#         <AxesSubplot:title={'center':'dur'}>,
#         <AxesSubplot:title={'center':'QoE_JT'}>,
#         <AxesSubplot:title={'center':'QoE_noStall'}>,
#         <AxesSubplot:title={'center':'QoE_noSwitches'}>,
#         <AxesSubplot:title={'center':'QoE_Linear'}>,
#         <AxesSubplot:title={'center':'QoE_Linear2'}>,
#         <AxesSubplot:title={'center':'QoE_Linear3'}>,
#         <AxesSubplot:title={'center':'QoE_LD_SD_HD'}>,
#         <AxesSubplot:title={'center':'QoE_ITU_023'}>,
#         <AxesSubplot:title={'center':'QoE_ITU_035'}>,
#         <AxesSubplot:title={'center':'QoE_ITU_046'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# If features are too many, we need to select some

# %%
df[['bitrates_144p','bitrates_240p']].hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'bitrates_144p'}>,
#         <AxesSubplot:title={'center':'bitrates_240p'}>]], dtype=object)

# %% [markdown]
# Each column counts the number of samples in the bin.
#
# Histograms are discretized versions of probability density functions.
#
# #### Binning

# %% [markdown]
# How many bins?
#
# If too few the density of the feature is badly approximated (note that with 3 bins we miss the 3 peaks).
#
# If too many, each bin risk to have only 1 or few samples.
#
# **Rule of thumb**: the more samples, the more bins, since each bin collects a sufficient number of points. Trial and error.

# %% [markdown]
# #### Group by
# How does the distribution of a feature changes with the quality?

# %%
# sharex imposes all the plots to have the same x range
# (otherwise visual comparison is different).
df[['67101', 'Film & Animation']].hist(figsize=(20,15), by='Film & Animation',
                                    sharex=True, bins=5)
# Out:
# array([[<Axes: title={'center': 'Autos & Vehicles'}>,
#         <Axes: title={'center': 'Comedy'}>,
#         <Axes: title={'center': 'Education'}>,
#         <Axes: title={'center': 'Entertainment'}>],
#        [<Axes: title={'center': 'Film & Animation'}>,
#         <Axes: title={'center': 'Gaming'}>,
#         <Axes: title={'center': 'Howto & Style'}>,
#         <Axes: title={'center': 'Movies'}>],
#        [<Axes: title={'center': 'Music'}>,
#         <Axes: title={'center': 'News & Politics'}>,
#         <Axes: title={'center': 'Nonprofits & Activism'}>,
#         <Axes: title={'center': 'People & Blogs'}>],
#        [<Axes: title={'center': 'Pets & Animals'}>,
#         <Axes: title={'center': 'Science & Technology'}>,
#         <Axes: title={'center': 'Shows'}>,
#         <Axes: title={'center': 'Sports'}>],
#        [<Axes: title={'center': 'Trailers'}>,
#         <Axes: title={'center': 'Travel & Events'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# As expected, the higher the quality, the more ```ReceivedBytes``` concentrate toward higher values. However, we also see that we have not so many samples and we cannot trust the histogram too much.
#
# **Useful for classification**
#
# We can build a simple classifier: ```if BytesReceived >= threshold ==> 720p```

# %% [markdown]
# # Correlations

# %% [markdown]
# How do feature relate each other?
#
# Use `scatter_matrix`. If the dataset is big, it would take too long. Let just selects few columns. For instance, the overall metrics (not the connection-wise metrics)

# %%
# We first define a function to change the
# rotation of the text in the plot


# The following method takes too long
#     sm = scatter_matrix(df)


# Let us just consider some features
columns_to_plot = ['bitrates_144p','bitrates_240p',
                       'bitrates_360p', 'bitrates_480p',
                        'bitrates_720p',
                        'bitrates_1080p', 'totalDuration',
                       'totalPacketCount', 'join_time']
sm = scatter_matrix(df[columns_to_plot],
                   figsize=(10,10))

plt.show()

# %% [markdown]
# If we want to rotate labels, I prepared a function in the course library `visualization`

# %%
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/emilien/.local/lib/python3.10/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/emilien/.local/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /home/emilien/.local/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=3 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: cycler>=0.10 in /home/emilien/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/emilien/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
import visualization
# Out:
# --2026-05-19 11:54:36--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/visualization.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13023 (13K) [text/plain]
# Saving to: ‘visualization.py.3’
#
# visualization.py.3  100%[===================>]  12.72K  --.-KB/s    in 0.003s
#
# 2026-05-19 11:54:36 (4.81 MB/s) - ‘visualization.py.3’ saved [13023/13023]

# %% [markdown]
# Let's see what is inside the module I prepared

# %%
help(visualization)
# Out:
# Help on module visualization:
#
# NAME
#     visualization
#
# FUNCTIONS
#     evaluate_anomaly_detector(y_train, anomaly_scores, threshold_selected=None)
#         Evaluates the results from anomaly detection
#
#     false_positive_rate(y_true, y_pred)
#
#     plot_conf_mat(y_true, y_pred, class_names, normalize=True, title=None, cmap=<matplotlib.colors.ListedColormap object at 0x7e470c0cb450>, text=True, width=8, height=8)
#         This function prints and plots the confusion matrix.
#         In case of errors, you may need to do
#                         class_names = np.array(class_names)
#         before calling this function.
#
#
#         Parameters:
#         --------------------------
#         target: The array of the true categories. It contains as many values
#                         as the number of samples. Each value is an integer number
#                         corresponding to a certain category. This array represents
#                         the true category of each sample.
#
#         predicted:      It has the same format, but it does not represent the true
#                                 category, rather it represents the result of a model.
#
#         class_names:    Array of strings, where the first. The k-th element
#                                         is the name of the k-th class
#
#         normalize:      (default=True) If False, it just prints the number of values in
#                                         each cell. Otherwise it prints the frequencies, i.e.
#                                         the sum over each row is 1
#
#         title:  (default=None) Title of the figure
#
#         cmap:   (default=plt.cm.viridis) Color map
#
#         text:   (default=True) If True it prints numerical values on each cell. Otherwise
#                         it just shows the colors
#
#
#         width:  (default=8) Of the figure
#
#         height: (default=8) Of the figure
#
#     plot_corr(df, width, height, print_value, thresh=0)
#         This function plots a correlation plot
#
#         Parameters
#         ------------
#         df: dataframe
#                     The dataframe of which we want to show
#                     the correlation
#         width : int
#             The width of the figure
#         height : int
#             The height of the figure
#         print_value : bool
#             If True, it prints the Pearson's
#             correlation coefficient values in
#             the picture
#         thresh : float
#             No color will be shown if the correlation
#             value is below this threshold
#             in absolute value
#
#     plot_feature_importances(importances, feature_names)
#         Plots the feature importance with bars.
#
#         To use with Random Forest Classifiers or Regressors.
#
#         Parameters:
#         --------------
#         importances: the list of values of feature importances. You can get
#                                       it as model.feature_importances (if model is the name of
#                                       your Random Forest model)
#         feature_names: the list of feature names
#
#         Credits to spies006: https://stackoverflow.com/a/44102451/2110769
#
#     plot_precision_recall_curve(y_train, anomaly_scores, ax, threshold_selected=None)
#         Inspired by
#           http://abhay.harpale.net/blog/machine-learning/threshold-tuning-using-roc/
#
#     plot_precision_recall_vs_thresholds(y_train, anomaly_scores, ax, threshold_selected=None)
#         From Fig.3.4 of Geron, Hands-On Machine Learning with Scikit-Learn,
#           Keras, and TensorFlow, O'Reilly 2019
#
#     plot_roc_curve(y_train, anomaly_scores, ax, threshold_selected=None)
#         Inspired by
#           http://abhay.harpale.net/blog/machine-learning/threshold-tuning-using-roc/
#
#     plot_tpr_fpr_vs_thresholds(y_train, anomaly_scores, ax, threshold_selected=None)
#         Inspired by Fig.3.4 of Geron, Hands-On Machine Learning with Scikit-Learn,
#           Keras, and TensorFlow, O'Reilly 2019
#
#     rotate_labels(sm)
#         Rotate the labels of a scatter matrix
#
#         Parameters
#         -----------------
#         sm: scatter matrix
#
#     silhouette_diagram(X_, cluster_labels, n_clusters, sample_size=None, random_state=None, title='Silhouette diagram')
#         This code is based on scikit learn documentation:
#         https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html#sphx-glr-auto-examples-cluster-plot-kmeans-silhouette-analysis-py
#
#
#         Returns
#         ----------------
#         sample_silhouette_values: the silhouette value of each sample
#
# FILE
#     /mnt/c/users/emili/Desktop/git world/NET4550/Analyse/visualization.py

# %%
sm = scatter_matrix(df[columns_to_plot],
                   figsize=(10,10))
visualization.rotate_labels(sm)
plt.show()

# %% [markdown]
# Trivial correlations:
# * PacketsSent vs. BytesSent
# * PacketsReceived vs. BytesReceived
# * BufferHealth vs. BufferProgress
#
# Interesting correlations:
# * PacketsReceived vs. PacketsSent
# *  BufferHealth and BufferProgress are linearly dependent.
#     * While we reproduce the video, our ahead-buffer fills more and more
#
# * **BufferProgress**: (fraction of video downloaded into the browser buffer)
# * **BufferHealth**: (how many "future seconds of video" we already have in the buffer)
#
#
#
# Unfortunately, `label` is not plotted, since it is not numeric. Let us transform it in numerical form.

# %%
# Let us write our replacing function
def replace_function(label_text):
    if label_text=='bitrates_1080p':
        return 1080
    elif label_text=='bitrates_720p':
        return 720
    elif label_text=='bitrates_480p':
        return 480
    elif label_text=='bitrates_360p':
        return 360
    elif label_text=='bitrates_240p':
        return 240
    elif label_text=='bitrates_144p':
        return 144
    else :
        return 0

# Let us apply it, line by line
label_numeric = df['label'].apply(replace_function)

# Let us add this column to our dataframe
df['label_num'] = label_numeric
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/directml/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/directml/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/directml/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1510/4092387445.py in <module>
#      17
#      18 # Let us apply it, line by line
# ---> 19 label_numeric = df['label'].apply(replace_function)
#      20
#      21 # Let us add this column to our dataframe
#
# ~/miniconda3/envs/directml/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniconda3/envs/directml/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'label'

# %% [markdown]
# Let's plot the scatter_matrix again

# %%
#columns_to_plot.append('label_num')

# %%
sm = scatter_matrix(df[columns_to_plot],
                   figsize=(10,10))
visualization.rotate_labels(sm)
plt.show()

# %% [markdown]
# ## Pearson's correlation

# %% [markdown]
# It is a way to mathematically express correlation between two features $j,j'$. For each sample, we compute:
#     \begin{align}
#     \left( x_j^{(i)} - \mu_j \right) \cdot \left( x_{j'}^{(i)} - \mu_{j'} \right)
#     \end{align}
#
# Averaging across all samples, we obtain the **covariance between features** $j,j'$ ([wikipedia](https://en.wikipedia.org/wiki/Covariance#Calculating_the_sample_covariance))
#         \begin{align}
#         \text{Cov}(j,j') =
#     \frac{1}{m-1}\sum_{i=1}^m \left( x_j^{(i)} - \mu_j \right) \cdot \left( x_{j'}^{(i)} - \mu_{j'} \right)
#     \end{align}
#
# We divide by the standard deviations to normalize, and we obtain the **Person's correlation coefficient**
#     \begin{align}
#     \rho_{j,j'} = \frac{\text{Cov}(j,j')}{\sigma_j\cdot \sigma_{j'}}
#     \end{align}
#
# It can be shown that
#     $$ -1 \le \rho_{j,j'} \le 1
#     $$
#
# Examples of different values of Pearson correlation (in the picture it is indicated as $r$ instead of $\rho$), between $x$ and $y$ values. Note that when $\rho=1$ or $\rho=-1$, there is linear dependence between $x$ and $y$. We can say that Pearson's correlation measures how much much there is linear dependence between features.

# %% [markdown]
# <img src=https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/01.introduction/img/persons.png width=600>

# %% [markdown]
# (picture from [futurelearn](https://www.futurelearn.com/info/courses/data-analytics-for-business-manipulating-and-interpreting-your-data/0/steps/177516)).

# %% [markdown]
# * Based on the plot above, what do you expect $\rho_{j,j'}$ to be between `PacketsReceived` and `PacketsSent`?

# %%
corrmatrix = df.corr()
corrmatrix
# Out:
#                bitrates_144p  bitrates_240p  bitrates_360p  bitrates_480p  \
# bitrates_144p       1.000000       0.836863       0.832305       0.801701
# bitrates_240p       0.836863       1.000000       0.992792       0.978845
# bitrates_360p       0.832305       0.992792       1.000000       0.992395
# bitrates_480p       0.801701       0.978845       0.992395       1.000000
# ...                    ...           ...          ...          ...
# QoE_Linear3       1.000000      0.896880     0.481415     0.835137
# QoE_LD_SD_HD      0.896880      1.000000     0.311109     0.787834
# QoE_ITU_023       0.481415      0.311109     1.000000     0.723102
# QoE_ITU_035       0.835137      0.787834     0.723102     1.000000
# QoE_ITU_046       0.837769      0.788075     0.739888     0.994722
#
#                QoE_ITU_046
# bitrates_144p    -0.090256
# bitrates_240p    -0.106056
# bitrates_360p    -0.107644
# bitrates_480p    -0.107934
# bitrates_720p    -0.106248
# ...                    ...
# QoE_Linear3       0.837769
# QoE_LD_SD_HD      0.788075
# QoE_ITU_023       0.739888
# QoE_ITU_035       0.994722
# QoE_ITU_046       1.000000
#
# [268 rows x 268 columns]

# %%
corrmatrix = corrmatrix.round(2)
corrmatrix
# Out:
#                bitrates_144p  bitrates_240p  bitrates_360p  bitrates_480p  \
# bitrates_144p           1.00           0.84           0.83           0.80
# bitrates_240p           0.84           1.00           0.99           0.98
# bitrates_360p           0.83           0.99           1.00           0.99
# bitrates_480p           0.80           0.98           0.99           1.00
# bitrates_720p           0.79           0.95           0.97           0.99
# ...                      ...            ...            ...            ...
# QoE_Linear3            -0.15          -0.16          -0.16          -0.16
# QoE_LD_SD_HD           -0.20          -0.23          -0.23          -0.23
# QoE_ITU_023            -0.02          -0.02          -0.02          -0.02
# QoE_ITU_035            -0.08          -0.10          -0.10          -0.10
# QoE_ITU_046            -0.09          -0.11          -0.11          -0.11
#
#                bitrates_720p  bitrates_1080p  join_time  stallingNumber  \
# bitrates_144p           0.79            0.79       0.02            0.03
# bitrates_240p           0.95            0.91       0.02            0.03
# bitrates_360p           0.97            0.93       0.02            0.03
# bitrates_480p           0.99            0.95       0.02            0.03
# bitrates_720p           1.00            0.98       0.02            0.03
# ...                      ...             ...        ...             ...
# QoE_Linear3            -0.16           -0.15      -0.63           -0.24
# QoE_LD_SD_HD           -0.23           -0.22      -0.39           -0.22
# QoE_ITU_023            -0.02           -0.02      -0.65           -0.24
# QoE_ITU_035            -0.10           -0.09      -0.51           -0.18
# QoE_ITU_046            -0.11           -0.10      -0.50           -0.25
#
#                totalStallDuration  outbandQoS_DL_TP  ...  QoE_JT  QoE_noStall  \
# bitrates_144p                0.01             -0.01  ...   -0.01         0.03
# bitrates_240p                0.01             -0.00  ...   -0.01         0.03
# bitrates_360p                0.01             -0.00  ...   -0.01         0.03
# bitrates_480p                0.01             -0.00  ...   -0.01         0.03
# bitrates_720p                0.01             -0.00  ...   -0.01         0.03
# ...                           ...               ...  ...     ...          ...
# QoE_Linear3                 -0.13              0.57  ...    0.59        -0.25
# QoE_LD_SD_HD                -0.10              0.57  ...    0.35        -0.25
# QoE_ITU_023                 -0.14              0.25  ...    0.65        -0.19
# QoE_ITU_035                 -0.09              0.52  ...    0.48        -0.20
# QoE_ITU_046                 -0.12              0.53  ...    0.47        -0.27
#
#                QoE_noSwitches  QoE_Linear  QoE_Linear2  QoE_Linear3  \
# bitrates_144p            0.24       -0.16        -0.15        -0.15
# bitrates_240p            0.23       -0.17        -0.17        -0.16
# bitrates_360p            0.23       -0.17        -0.17        -0.16
# bitrates_480p            0.23       -0.17        -0.17        -0.16
# bitrates_720p            0.23       -0.17        -0.16        -0.16
# ...                       ...         ...          ...          ...
# QoE_Linear3             -0.19        0.98         0.99         1.00
# QoE_LD_SD_HD            -0.31        0.86         0.88         0.90
# QoE_ITU_023              0.20        0.52         0.51         0.48
# QoE_ITU_035             -0.16        0.83         0.83         0.84
# QoE_ITU_046             -0.16        0.83         0.84         0.84
#
#                QoE_LD_SD_HD  QoE_ITU_023  QoE_ITU_035  QoE_ITU_046
# bitrates_144p         -0.20        -0.02        -0.08        -0.09
# bitrates_240p         -0.23        -0.02        -0.10        -0.11
# bitrates_360p         -0.23        -0.02        -0.10        -0.11
# bitrates_480p         -0.23        -0.02        -0.10        -0.11
# bitrates_720p         -0.23        -0.02        -0.10        -0.11
# ...                     ...          ...          ...          ...
# QoE_Linear3            0.90         0.48         0.84         0.84
# QoE_LD_SD_HD           1.00         0.31         0.79         0.79
# QoE_ITU_023            0.31         1.00         0.72         0.74
# QoE_ITU_035            0.79         0.72         1.00         0.99
# QoE_ITU_046            0.79         0.74         0.99         1.00
#
# [268 rows x 268 columns]

# %% [markdown]
# #### Visualization
# In the library `visualization`, I prepared a function to easily visualize correlations. We need to import it:

# %%
visualization.plot_corr(df, width=10, height=5,
                        print_value=True)

# %% [markdown]
# Better not to write the values

# %%
visualization.plot_corr(df, width=15, height=15,
                        print_value=False)

# %% [markdown]
# If we focus on `label_num`, it seems that features starting from `pcapStats_stats_p10_DL_t` up to `pcapStats_stats_p90_DL_t` dot not have a large correlation with `label_num`. Let's remove them to make our correlation plot clearer.

# %%
# Retrieve the positions of the features we want to remove
indexOfBytesReceived3 = list(df.columns).index('pcapStats_stats_p20_DL_t')
indexOfProtocol25 = list(df).index('pcapStats_first30sec_DLTP_t27')

# %%
# We put the feature names we want to keep in the list columns_to_focus.

columns_to_focus = df.columns[0:indexOfBytesReceived3+1]
columns_to_focus = columns_to_focus.append(df.columns[indexOfProtocol25:])

visualization.plot_corr(df[columns_to_focus], width=20, height=20,
                        print_value=False)

# %% [markdown]
# #### Feature importance (based on Person's correlation)

# %% [markdown]
# What are the most correlated features to `label_num`?

# %%
# From the course library
! wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
import feature_engineering

help(feature_engineering)
# Out:
# --2026-05-19 12:11:45--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/course_library/feature_engineering.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2593 (2.5K) [text/plain]
# Saving to: ‘feature_engineering.py’
#
# feature_engineering 100%[===================>]   2.53K  --.-KB/s    in 0s
#
# 2026-05-19 12:11:46 (4.97 MB/s) - ‘feature_engineering.py’ saved [2593/2593]
#
# Help on module feature_engineering:
#
# NAME
#     feature_engineering
#
# FUNCTIONS
#     get_features_correlated_to_target(df, target_feature)
#         Returns the Pearson's correlation coefficient between the
#         features and the target
#
#         Parameters
#         ------------
#         df_: dataframe
#
#         target_feature: string
#                 the name of the target feature
#
#         Returns
#         --------------
#         Series
#                 A series of features, with the Person's correlation
#                 coefficient between them and the target, ordered in decreasing
#                 oder of correlation
#
#     get_most_correlated(df)
#         Returns the pairs of features in descending order of Person's
#         correlation
#
#         Parameters
#         --------------
#         df: dataframe
#
#         Returns
#         -------------
#         Series
#                 the pair of features and the Pearson's coefficient
#
#     low_var_features(df, threshold)
#         Returns the features whose variance is
#         above the threshold
#
#         Parameters
#         ------------
#         df: dataframe
#         threshold : float
#
#         Returns
#         -----------
#         list
#             the names of the features whose variance is below
#             the threshold
#
# FILE
#     /mnt/c/users/emili/Desktop/git world/NET4550/Analyse/feature_engineering.py

# %%
features_corr = \
        feature_engineering.get_features_correlated_to_target(
                df, target_feature='totalPacketCount')

features_corr[:12]
# Out:
# totalPacketCount           1.00
# chunkSizesPcap_avg         0.86
# chunkSizesPcap_p75         0.82
# videoChunkSizesHTTP_avg    0.80
# chunkSizesPcap_p50         0.80
# videoChunkSizesHTTP_p50    0.79
# chunkSizesPcap_std         0.75
# videoChunkSizesHTTP_p25    0.74
# videoChunkSizesHTTP_p75    0.72
# numberOfVideoChunks        0.69
# chunkSizesPcap_max         0.69
# chunkSizesPcap_p25         0.68
# Name: totalPacketCount, dtype: float64

# %% [markdown]
# The most correlated feature to the label_num are `chunkSizesPcap_avg ` and `chunkSizesPcap_p75`

# %%
features_corr
# Out:
# totalPacketCount              1.00
# chunkSizesPcap_avg            0.86
# chunkSizesPcap_p75            0.82
# videoChunkSizesHTTP_avg       0.80
# chunkSizesPcap_p50            0.80
#                               ...
# pcapStats_stats_p80_DL_pkt   -0.03
# totalSwitchesAccumalate      -0.02
# videoChunkDursHTTP_min        0.02
# pcapStats_stats_max_DL_pkt   -0.02
# pcapStats_stats_p70_DL_pkt    0.01
# Name: totalPacketCount, Length: 268, dtype: float64

# %% [markdown]
# ### Limits of Pearson's correlation

# %% [markdown]
# Correlation does not capture all types of dependencies. Suppose you have two features as follows:

# %%
invented_df = pd.DataFrame()
invented_df['x'] = np.arange(-10,11,1)
invented_df['y'] = invented_df['x'] * invented_df['x']

invented_df
# Out:
#      x    y
# 0  -10  100
# 1   -9   81
# 2   -8   64
# 3   -7   49
# 4   -6   36
# 5   -5   25
# 6   -4   16
# 7   -3    9
# 8   -2    4
# 9   -1    1
# 10   0    0
# 11   1    1
# 12   2    4
# 13   3    9
# 14   4   16
# 15   5   25
# 16   6   36
# 17   7   49
# 18   8   64
# 19   9   81
# 20  10  100

# %%
plt.xlabel("x")
plt.ylabel("y")
plt.plot(invented_df['x'], invented_df['y'] )

# %% [markdown]
# Is there dependency between `x` and `y`? What is the correlation?

# %%
invented_df.corr().round(2)
# Out:
#      x    y
# x  1.0 -0.0
# y -0.0  1.0

# %% [markdown]
# If the Pearson's correlation is zero, it does not mean there is no dependency.
#
# Pearson's coefficient only captures monotonic dependency (if one increases the other increases/decreases).
#
# In our case:
# * Before 0 => Negative correlation
# * After 0 => Positive correlation
#
# But in general
# * 0-correlation

# %% [markdown]
# #### Additional details
#
# You can skip them, if not interested.

# %% [markdown]
# ***Finding more complex correlations***
# If Person's correlation cannot capture all the types of depedence between features, how can we capture them?
#
# There are practically two ways: (i) a-priori, i.e., before training any ML model, just by applying statistical tests or exploring data visually and (ii) a-posteriori, i.e., you first train a model and then you observe how it automatically chose the features to use the most.
#
# * A prori:
#   * Visually, using the scattermatrix
#     * (Recall that if there are too many features, you may pre-filter some just based on your intuition)
#   * You first transform one of the two features (see next section) and compute the correlation coefficient again
#   * If the two features are categorical, plot the histogram of one, fixing the value of the other, and see how this histogram changes (as we did in the "Group by" section of this notebook).
#   * Using statistical tests or more advance statistical measures (outside of the scope of this course)
#     * [Chi-Squared test](https://machinelearningmastery.com/chi-squared-test-for-machine-learning/): this test allows to answer the following question: Is there a dependence between two categorical features? Yes or not?
#     * `nlcor` uses heuristics to find non-linear relationships ([available in R](https://towardsdatascience.com/estimating-non-linear-correlation-in-r-62c6571cb1db) ).
#     * [Distance Correlation and Maximal Information Coefficient](https://www.freecodecamp.org/news/how-machines-make-predictions-finding-correlations-in-complex-data-dfd9f0d87889/).
# * A posteriori:
#   * You train a model using several features and then check, a posteriori, their "feature importance", i.e., how much the prediction of the model is impacted by them. We will see them in next lessons (don't worry if you don't fully understand them now):
#     * In a linear regression or logistic regression model, after scaling the dataset, the coefficient of each feature is an indication of importance
#     * Random forests also return a feature importance value
#     * Each method may have its own specific way of expressioning feature importance.
#   * [Permutation feature importance](https://scikit-learn.org/stable/modules/permutation_importance.html)

# %% [markdown]
# # Transformation

# %% [markdown]
# Correlations are sometimes unclear, due to the fact that some features may be **skewed** like the following.

# %%
cols = ['KBytesReceived','label_num']
sm = scatter_matrix(df_cleaned[cols],
                   figsize=(10,10))

# %% [markdown]
# There are many samples crowded together around low values of `PacketsSent`. We would like to "zoom in" into those values to discern them.

# %%
df_cleaned['KBytesReceived_log'] = np.log(df_cleaned['KBytesReceived'])

# %%
cols = ['KBytesReceived_log','label_num']
sm = scatter_matrix(df_cleaned[cols],
                   figsize=(10,10))

# %% [markdown]
# What changed:
# * Values of KBytesReceived are better spread
# * Looking at `label_num` vs. `KBytesReceived_log`, the values are less squashed down
#
# This let correlation better emerge:

# %%
corrmatrix = df_cleaned.corr()
print("Original correlation: ", corrmatrix['KBytesReceived']['label_num'],
     "; Correlation after transformation: ",
     corrmatrix['KBytesReceived_log']['label_num'])
# Out:
# Original correlation:  0.26444253489122005 ; Correlation after transformation:  0.3399134831774235

# %% [markdown]
# #### Transform multiple features at a time.

# %% [markdown]
# Let's check what are the features that would benefit from log-transformation

# %%
sm = scatter_matrix(df_cleaned[columns_to_plot],
                   figsize=(10,10))
visualization.rotate_labels(sm)

plt.show()

# %% [markdown]
# They are
# `PacketsSent`, `PacketsReceived`, `BytesSent`, `BytesReceived`,`BufferProgress`

# %%
cols_to_transform = ['PacketsSent','PacketsReceived','BytesSent',
                  'BytesReceived','BufferProgress'];

cols_transformed = [s + "_log" for s in cols_to_transform]


df_cleaned[cols_transformed] = df_cleaned[cols_to_transform].transform(
                        func=lambda x : np.log(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# **Attention**: The previous code returned an error! In effect log(0) is not defined. It's safer to use the transformation log(1+x)

# %%
df_cleaned[cols_transformed] = df_cleaned[cols_to_transform].transform(
                        func=lambda x : np.log(1+x))

# %% [markdown]
# Let's print again the scattermatrix, replacing the original features with the transformed ones.

# %%
columns_to_plot_after_transf = columns_to_plot.copy()
for feature in cols_to_transform:
    columns_to_plot_after_transf.remove(feature)

for feature in cols_transformed:
    columns_to_plot_after_transf.insert(0,feature)

# %%
sm = scatter_matrix(df_cleaned[columns_to_plot_after_transf],
                   figsize=(10,10))
visualization.rotate_labels(sm)

plt.show()

# %% [markdown]
# Let's check the most correlated features to `label_num`.

# %%
feature_engineering.get_features_correlated_to_target(df_cleaned,
                                    target_feature='label_num').head(10)
# Out:
# label_num              1.00
# StartTime             -0.41
# EpochTime             -0.41
# PacketsSent            0.38
# PacketsSent0           0.36
# PacketsReceived_log    0.34
# KBytesReceived_log     0.34
# BytesReceived_log      0.34
# BytesSent0             0.30
# PacketsSent_log        0.26
# Name: label_num, dtype: float64

# %% [markdown]
# Before adding the transformed features, the most correlated features were

# %%
features_corr.head(10)
# Out:
# label_num          1.00
# StartTime         -0.41
# EpochTime         -0.41
# PacketsSent        0.38
# PacketsSent0       0.36
# BytesSent0         0.30
# BytesReceived      0.26
# KBytesReceived     0.26
# PacketsReceived    0.25
# BytesSent3        -0.23
# Name: label_num, dtype: float64

# %% [markdown]
# We have unveiled more correlation in our data than it was before. It will be very useful to produce better models

# %% [markdown]
# ### Which transformation?

# %% [markdown]
# There are many possible transformation you could use: see [here](https://medium.com/@TheDataGyan/day-8-data-transformation-skewness-normalization-and-much-more-4c144d370e55) and [here](https://medium.com/@ODSC/transforming-skewed-data-for-machine-learning-90e6cc364b0) . How would we choose?
#
# * Visual inspection: you plot a variable vs. another and you apply some rules of thumb
#    * If the values of a certain feature concentrate a lot on low values, apply `log`
#    * In general, you can plot a feature vs. the target label, and if you recognize the shape of a well-known function, apply the corresponding transformation. The well-known functions in the following figure capture in a quite complete way the kinds of dependence you may find between a feature and the target. But, you have no limits, you can choose a non-linear transformation based on your fantasy, your intuition and your experience.
#
#    ![alt text](https://miro.medium.com/max/1262/1*iEbD3x2S5KOiEI6ZOltp9w.png)
#
#           Picture from randerson112358's [post](https://medium.com/@randerson112358/algorithm-analysis-time-complexity-simplified-cd39a81fec71) on medium.com
#
# * Another alternative: you train a model capable of catpuring non-linearities (polynomial regression, linear network, random forests) and you let it transform the features automatically, for you.
# * Use [Generalized Additive Models](https://youtu.be/f9Rj6SHPHUU) (outside our scope): they are able to choose the right transformation within a family of possible transformations.

# %% [markdown]
# # References
#
# [1] Gutterman, C., Guo, K., Arora, S., Wang, X., Wu, L., Katz-Bassett, E., & Zussman, G. (2019). Requet: Real-time QoE detection for encrypted YouTube traffic. In ACM MMSys.

# %%
df_cleaned.to_csv('df.A_2.csv',index = None, header=True)
